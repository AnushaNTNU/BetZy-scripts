# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# Load data
file1 = '/cluster/shared/noresm/inputdata/lnd/clm2/surfdata_map/release-clm5.0.18/landuse.timeseries_1.9x2.5_SSP5-3.4_78pfts_CMIP6_simyr1850-2100_c190228.nc'
file3 = '/cluster/shared/noresm/inputdata/mdeb/landuse.timeseries_1.9x2.5_SSP5-3.4_78pfts_sugarcane.nc'
dset1 = xr.open_dataset(file1, decode_times=False)
dset3 = xr.open_dataset(file3, decode_times=False)

# Rename dimensions and assign coordinates
dset1 = dset1.rename_dims({'lsmlat': 'Latitude', 'lsmlon': 'Longitude'})
dset1 = dset1.assign_coords(Latitude=dset1['LATIXY'][:, 0].values)
dset1 = dset1.assign_coords(Longitude=dset1['LONGXY'][0, :].values)

dset3 = dset3.rename_dims({'lsmlat': 'Latitude', 'lsmlon': 'Longitude'})
dset3 = dset3.assign_coords(Latitude=dset3['LATIXY'][:, 0].values)
dset3 = dset3.assign_coords(Longitude=dset3['LONGXY'][0, :].values)

# Calculate crop area
dset1['PCT_CFT_area'] = (dset1['PCT_CFT'] / 100) * dset1['AREA'] * (dset1['PCT_CROP'] / 100) * dset1['LANDFRAC_PFT']
dset3['PCT_CFT_area'] = (dset3['PCT_CFT'] / 100) * dset3['AREA'] * (dset3['PCT_CROP'] / 100) * dset3['LANDFRAC_PFT']

# Calculate differences
cropinc_values = dset3['PCT_CFT_area'] - dset1['PCT_CFT_area']

# Summarize crop area in 2100
Cropareaincrease_2100 = cropinc_values.isel(time=-1).sum(['Latitude', 'Longitude'])

# Create bar plot
sorted_indices = np.argsort(Cropareaincrease_2100.values)[::-1]
sorted_data_values = Cropareaincrease_2100.values[sorted_indices]

plt.figure(figsize=(15, 4))

# Generating bar plots for the frequency/count of each category side by side
plt.bar(index, sorted_data_values, bar_width, label='Sugarcane Landuse')
plt.bar(index + bar_width, sorted_datadef_values, bar_width, label='Default Landuse')

plt.xlabel('Type of Crops')
plt.ylabel('Area (Km2)')
plt.title('Croparea in 2100')
plt.xticks(index + bar_width / 2, sorted_indices)  # Set x-ticks at the center of each group with sorted indices
plt.legend()  # Display legend with labels
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# Open the datasets
file1 = '/cluster/shared/noresm/inputdata/lnd/clm2/surfdata_map/release-clm5.0.18/landuse.timeseries_1.9x2.5_SSP5-3.4_78pfts_CMIP6_simyr1850-2100_c190228.nc'     # SSP534
dset1 = xr.open_dataset(file1, decode_times=False)
dset1 = dset1.rename_dims({'lsmlat': 'Latitude', 'lsmlon': 'Longitude'})
dset1 = dset1.assign_coords(Latitude=dset1['LATIXY'][:,0].values, Longitude=dset1['LONGXY'][0,:].values)

file3 = '/cluster/shared/noresm/inputdata/mdeb/landuse.timeseries_1.9x2.5_SSP5-3.4_78pfts_sugarcane.nc'     # modified for sugarcane
dset3 = xr.open_dataset(file3, decode_times=False)
dset3 = dset3.rename_dims({'lsmlat': 'Latitude', 'lsmlon': 'Longitude'})
dset3 = dset3.assign_coords(Latitude=dset3['LATIXY'][:,0].values, Longitude=dset3['LONGXY'][0,:].values)

# Calculate the area of specific crop type
dset1['PCT_CFT_area'] = (dset1['PCT_CFT']/100) * dset1['AREA'] * (dset1['PCT_CROP']/100) * dset1['LANDFRAC_PFT']
dset3['PCT_CFT_area'] = (dset3['PCT_CFT']/100) * dset3['AREA'] * (dset3['PCT_CROP']/100) * dset3['LANDFRAC_PFT']

# Extract values for 2100 from the datasets
Cropareaincrease_2100 = dset1['PCT_CFT_area'].isel(time=-1).sum(['Latitude', 'Longitude']).values
Cropareadefault_2100 = dset3['PCT_CFT_area'].isel(time=-1).sum(['Latitude', 'Longitude']).values

# Create a bar plot for crop area in 2100
plt.figure(figsize=(15, 4))
plt.bar(['Sugarcane Landuse', 'Default Landuse'], [Cropareaincrease_2100, Cropareadefault_2100])
plt.xlabel('Type of Crops')
plt.ylabel('Area (Km2)')
plt.title('Croparea in 2100')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 26>()
#      24 # Create a bar plot for crop area in 2100
#      25 plt.figure(figsize=(15, 4))
# ---> 26 plt.bar(['Sugarcane Landuse', 'Default Landuse'], [Cropareaincrease_2100, Cropareadefault_2100])
#      27 plt.xlabel('Type of Crops')
#      28 plt.ylabel('Area (Km2)')
#
# File /cluster/projects/nn9576k/conda_envs/jupyter/lib/python3.8/site-packages/matplotlib/pyplot.py:2375, in bar(x, height, width, bottom, align, data, **kwargs)
#    2371 @_copy_docstring_and_deprecators(Axes.bar)
#    2372 def bar(
#    2373         x, height, width=0.8, bottom=None, *, align='center',
#    2374         data=None, **kwargs):
# -> 2375     return gca().bar(
#    2376         x, height, width=width, bottom=bottom, align=align,
#    2377         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
